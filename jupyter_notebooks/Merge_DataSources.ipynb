# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import all 3 sources of data

# %%
vhdb = pd.read_csv("Virus_Host_DB.txt", delimiter="\t", header=None, names=['phage', 'host'])
vhdb.head(1)
# Out:
#        phage         host
# 0  NC_001447  NC_010163.1

# %%
phnew = pd.read_csv("phages_to_host.csv", header=0)
phnew = phnew[['phage_genbank_id','phage_refseq_id', 'host_id']]
phnew = phnew.rename(columns={"phage_genbank_id": "phage", 
                              "host_id": "host", 
                              "phage_refseq_id":"refseq"})
phnew.drop(phnew[phnew['host'] == 'Not Found'].index, inplace = True) 
phnew.head(1)
# Out:
#       phage     refseq        host
# 0  KJ410132  NC_023597  MT818425.1

# %%
CNNtr = pd.read_csv("training_set.csv", delimiter="\t")
CNNte = pd.read_csv("test_set.csv", delimiter="\t")
t1    = CNNtr[CNNtr['class'] == 1]
t2    = CNNte[CNNte['class'] == 1]
CNN   = pd.concat([t1, t2])
CNN.head(1)
# Out:
#         phage      host  class
# 20  NC_026583  CP027541      1

# %% [markdown]
# ## Basic Statistics

# %%
vhdbhosts  = set(vhdb['host'].to_numpy())
CNNhosts   = set(CNN['host'].to_numpy())
phnewhosts = set(phnew['host'].to_numpy())     # INCORRECT

# %%
vhdbphage  = set(vhdb['phage'].to_numpy())
CNNphage   = set(CNN['phage'].to_numpy())
phnewphage = set(phnew['phage'].to_numpy())

# %%
print("{} Pairs, {} unique phage, {} unique host in Virus-Host DB".format(vhdb.shape, len(vhdbphage), len(vhdbhosts)))
print("{} Pairs, {} unique phage, {} unique host in PhageDB".format(phnew.shape, len(phnewphage), len(phnewhosts)))
print("{} Pairs, {} unique phage, {} unique host in CNN paper data".format(CNN.shape, len(CNNphage), len(CNNhosts)))
# Out:
# (1707, 2) Pairs, 1679 unique phage, 261 unique host in Virus-Host DB
# (3469, 3) Pairs, 3179 unique phage, 79 unique host in PhageDB
# (3469, 3) Pairs, 3449 unique phage, 301 unique host in CNN paper data

# %% [markdown]
# <p style="color:blue"> Because we see that most phages are unique, we can use it as foreign key to deduplicate phage-host pair. Also, PhageDB has inaccurate host id; CNN paper compiled PhageDB data back in March 2019 (so there should be a sufficient amount of overlap); Virus-Host DB data are all RefSeq (which is better than Genebank id since RefSeq is maintained by NCBI and all the RefSeq id for the bacteria are supposedly "representative") <p/>

# %% [markdown]
# ## Merge

# %%
def merge_into(dbA, dbB):
    """ We will merge database B into 
        database A by leveraging the 
        fact that most phages occurred 
        only once (and with a unique ID)
        So we essentially are unifying 
        the bacteria (host) accession number.
    """
    
    phage_map, host_map, suspicious = {}, {}, {}
    
    for phage in dbA['phage']:
        a = dbA[dbA['phage'] == phage]
        b = dbB[dbB['phage'] == phage]
        if not len(b) and dbB.shape[1] == 3:
            b = dbB[dbB['refseq'] == phage]

        # limit us to only one-to-one mapping
        if len(a) == len(b) and len(b) == 1:
            anumber = a['host'].to_numpy()[0]
            bnumber = b['host'].to_numpy()[0]
            
            if bnumber in suspicious:
                suspicious[bnumber].add(anumber)
                continue
            elif bnumber not in host_map:
                host_map[bnumber] = anumber
            elif (bnumber in host_map and 
                  host_map[bnumber] != anumber):
                r = host_map.pop(bnumber)
                suspicious[bnumber] = set({r, anumber})
            
            phage_map[b['phage'].to_numpy()[0]] = phage
            
        # If duplicates exist in dbB
        if len(a) > 1 and len(b) > 1:
            print(a.to_numpy())
            print(b.to_numpy())
           
    return phage_map, host_map, suspicious

# %% [markdown]
# #### Merge PhageDB into CNN First

# %%
phage_map, host_map, suspicious = merge_into(CNN, phnew)

# %%
suspicious
# Out:
# {'MN294681.1': {'CP019892', 'NZ_QTTZ01000001'},
#  'LT708304.1': {'CP027541', 'NZ_CM001149'}}

# %%
for k,v in host_map.items():
    phnew = phnew.replace(k, v)
for k,v in phage_map.items():
    phnew = phnew.replace(k, v)
cp_ = pd.concat((CNN[['phage', 'host']], 
                 phnew[['phage', 'host']]), axis=0, ignore_index=True)
cp_combined = cp_.drop_duplicates()
cp_combined.shape
# Out:
# (4731, 2)

# %% [markdown]
# #### Merge CP combined into VirusHost DB

# %%
phage_map, host_map, suspicious = merge_into(vhdb, cp_combined)
# Out:
# [['NC_004687' 'NZ_LN831039.1']
#  ['NC_004687' 'NZ_CP011491.1']]
# [['NC_004687' 'CP027541']
#  ['NC_004687' 'CP020809']]
# [['NC_004687' 'NZ_LN831039.1']
#  ['NC_004687' 'NZ_CP011491.1']]
# [['NC_004687' 'CP027541']
#  ['NC_004687' 'CP020809']]
# [['NC_003387' 'NZ_AP012555.1']
#  ['NC_003387' 'NZ_LN831039.1']]
# [['NC_003387' 'CP027541']
#  ['NC_003387' 'CP018363']]
# [['NC_003387' 'NZ_AP012555.1']
#  ['NC_003387' 'NZ_LN831039.1']]
# [['NC_003387' 'CP027541']
#  ['NC_003387' 'CP018363']]

# %%
for k,v in host_map.items():
    cp_combined = cp_combined.replace(k, v)
for k,v in phage_map.items():
    cp_combined = cp_combined.replace(k, v)
combined = pd.concat((cp_combined[['phage', 'host']], 
                 vhdb[['phage', 'host']]), axis=0, ignore_index=True)
combined = combined.drop_duplicates()
combined.shape
# Out:
# (5688, 2)

# %% [markdown]
# ### Verify Merging

# %%
from Bio import SeqIO, Entrez
import pandas as pd
import time

Entrez.email = "garycloudyang@gmail.com"

# %% [markdown]
# #### Extract host taxonomy information

# %%
hs = set(combined['host'].to_list())

# %%
df = pd.DataFrame(columns=['accn', 'Name', 'Taxonomy'])
row = 0

for h in hs:
    handle = Entrez.efetch(db="nuccore", id=h, rettype="gb", retmode="xml")
    res = Entrez.read(handle)
    handle.close()
    df.loc[row] =  [h] + [res[0]['GBSeq_organism']] + [res[0]['GBSeq_taxonomy']]
    print(res[0]['GBSeq_taxonomy'])
    print(res[0]['GBSeq_organism'])
    row += 1
    time.sleep(0.1)
# Out:
# Bacteria; Chlamydiae; Chlamydiales; Chlamydiaceae; Chlamydia/Chlamydophila group; Chlamydia
# Chlamydia pneumoniae LPCoLN
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Halobacteriales; Haloarculaceae; Haloarcula
# Haloarcula hispanica N601
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio alginolyticus
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Leclercia
# Leclercia adecarboxylata
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Ruegeria
# Ruegeria pomeroyi DSS-3
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas sp.
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Salinivibrio
# Salinivibrio costicola
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xanthomonas
# Xanthomonas oryzae pv. oryzicola
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus pseudintermedius HKU10-03
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Pectobacterium
# Pectobacterium wasabiae CFBP 3304
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Hafniaceae; Edwardsiella
# Edwardsiella tarda
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus saprophyticus subsp. saprophyticus
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus delbrueckii subsp. delbrueckii
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Acinetobacter
# Acinetobacter soli NIPH 2899
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus helveticus
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas atlantica T6c
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Acinetobacter
# Acinetobacter guillouiae
# Bacteria; Actinobacteria; Actinomycetales; Actinomycetaceae; Actinomyces
# Actinomyces naeslundii
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Cronobacter
# Cronobacter sakazakii
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Dinoroseobacter
# Dinoroseobacter shibae DFL 12 = DSM 16493
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Haloferacales; Halorubraceae; Halorubrum
# Halorubrum sodomense
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Yersinia
# Yersinia enterocolitica
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus epidermidis
# Bacteria; Firmicutes; Clostridia; Clostridiales; Clostridiaceae; Clostridium
# Clostridium sporogenes
# Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hexapoda; Insecta; Pterygota; Neoptera; Holometabola; Hymenoptera; Apocrita; Aculeata; Apoidea; Apidae; Apis
# Apis mellifera lamarckii
# Bacteria; Proteobacteria; Gammaproteobacteria; Pasteurellales; Pasteurellaceae; Aggregatibacter
# Aggregatibacter actinomycetemcomitans
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Rhodobacter
# Candidatus Rhodobacter lobularis
# Bacteria; Proteobacteria; Betaproteobacteria; Neisseriales; Chromobacteriaceae; Iodobacter
# Iodobacter sp. H11R3
# Bacteria; Actinobacteria; Propionibacteriales; Propionibacteriaceae; Cutibacterium
# Cutibacterium acnes KPA171202
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces sp. OK228
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium foliorum
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Rhizobium/Agrobacterium group; Rhizobium
# Rhizobium gallicum bv. gallicum R602sp
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Yersinia
# Yersinia pseudotuberculosis
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Haloferacales; Halorubraceae; Halorubrum
# Halorubrum coriense DSM 10284
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus salivarius
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium glutamicum
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus
# Bacillus pumilus
# Bacteria; Cyanobacteria; Synechococcales; Leptolyngbyaceae; Leptolyngbya
# Leptolyngbya boryana NIES-2135
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia terrae
# Eukaryota; Haptista; Haptophyta; Prymnesiophyceae; Phaeocystales; Phaeocystaceae; Phaeocystis
# Phaeocystis globosa
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacteroides
# Mycobacteroides abscessus
# Bacteria; Fusobacteria; Fusobacteriales; Fusobacteriaceae; Fusobacterium
# Fusobacterium nucleatum subsp. polymorphum
# Bacteria; Actinobacteria; Micrococcales; Intrasporangiaceae; Tetrasphaera
# Tetrasphaera jenkinsii Ben 74
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Phyllobacteriaceae; Mesorhizobium
# Mesorhizobium loti
# Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hexapoda; Insecta; Pterygota; Neoptera; Holometabola; Diptera; Nematocera; Tipuloidea; Tipulidae; Tipula
# Tipula cockerelliana
# Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hexapoda; Insecta; Pterygota; Neoptera; Holometabola; Diptera; Nematocera; Culicoidea; Culicidae; Culicinae; Culicini; Culex; Culex
# Culex quinquefasciatus
# Bacteria; Deinococcus-Thermus; Deinococci; Thermales; Thermaceae; Thermus
# Thermus thermophilus HB8
# Eukaryota; Viridiplantae; Chlorophyta; core chlorophytes; Chlorophyceae; Chlamydomonadales; Dunaliellaceae; Dunaliella
# Dunaliella viridis
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Sinorhizobium/Ensifer group; Sinorhizobium
# Sinorhizobium meliloti
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium foliorum
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Ralstonia
# Ralstonia pickettii
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium xerosis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Leuconostocaceae; Leuconostoc
# Leuconostoc pseudomesenteroides
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Rhizobium/Agrobacterium group; Rhizobium
# Rhizobium etli
# Bacteria; Cyanobacteria; Nostocales; Nostocaceae; Trichormus
# Trichormus variabilis 0441
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio vulnificus MO6-24/O
# Eukaryota; Viridiplantae; Chlorophyta; Mamiellophyceae; Mamiellales; Mamiellaceae; Micromonas
# Micromonas pusilla CCMP1545
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Weeksellaceae; Riemerella
# Riemerella anatipestifer ATCC 11845 = DSM 15868
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Erwinia
# Erwinia pyrifoliae
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Acinetobacter
# Acinetobacter johnsonii ANC 3681
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas sp.
# Bacteria; Tenericutes; Mollicutes; Acholeplasmatales; Acholeplasmataceae; Acholeplasma
# Acholeplasma laidlawii PG-8A
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Nonlabens
# Nonlabens dokdonensis DSW-6
# Bacteria; Tenericutes; Mollicutes; Mycoplasmataceae; Mycoplasma
# Mycoplasma pulmonis UAB CTIP
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus thermophilus
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Nocardia
# Nocardia brasiliensis ATCC 700358
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Geobacillus
# Geobacillus stearothermophilus
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacterium; Mycobacterium avium complex (MAC)
# Mycobacterium avium subsp. hominissuis
# Bacteria; Actinobacteria; Micrococcales; Brevibacteriaceae; Brevibacterium
# Brevibacterium iodinum
# Bacteria; Actinobacteria; Micrococcales; Micrococcaceae; Arthrobacter
# Arthrobacter globiformis
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia sp.
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus mutans
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces cattleya NRRL 8057 = DSM 46488
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Citrobacter
# Citrobacter amalonaticus Y19
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Tenacibaculum
# Tenacibaculum maritimum
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactiplantibacillus
# Lactiplantibacillus plantarum
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactiplantibacillus
# Lactobacillus pentosus MP-10
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia sputi
# Bacteria; Chlamydiae; Chlamydiales; Chlamydiaceae; Chlamydia/Chlamydophila group; Chlamydia
# Chlamydia abortus LLG
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella canis ATCC 23365
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Shigella
# Shigella sonnei
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Geobacillus; Geobacillus thermoleovorans group
# Geobacillus kaustophilus HTA426
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus oralis subsp. oralis
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas agarici
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Sodalis
# Sodalis glossinidius str. 'morsitans'
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces; Streptomyces albidoflavus group
# Streptomyces coelicolor
# Bacteria; Bacteroidetes; Bacteroidia; Bacteroidales; Tannerellaceae; Parabacteroides
# Parabacteroides distasonis
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium foliorum
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio parahaemolyticus
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas syringae
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Enterobacter; Enterobacter cloacae complex
# Enterobacter cloacae subsp. cloacae
# Bacteria; Bacteroidetes; Bacteroidia; Bacteroidales; Bacteroidaceae; Bacteroides
# Bacteroides intestinalis DSM 17393
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Geobacillus; unclassified Geobacillus
# Geobacillus sp. Y4.1MC1
# Bacteria; Proteobacteria; Alphaproteobacteria; SAR116 cluster; Candidatus Puniceispirillum
# Candidatus Puniceispirillum marinum IMCC1322
# Bacteria; Proteobacteria; Alphaproteobacteria; Pelagibacterales; Pelagibacteraceae; Candidatus Pelagibacter
# Candidatus Pelagibacter ubique HTCC7217
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Haloferacales; Haloferacaceae; Haloferax
# Haloferax lucentense DSM 14919
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Carnivora; Feliformia; Felidae; Felinae; Felis
# Felis catus
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Pectobacterium
# Pectobacterium atrosepticum
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Pantoea; Pantoea agglomerans group
# Pantoea agglomerans
# Eukaryota; Viridiplantae; Chlorophyta; core chlorophytes; Trebouxiophyceae; Chlorellales; Chlorellaceae; Chlorella clade; Chlorella
# Chlorella variabilis
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia alkanivorans
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Artiodactyla; Whippomorpha; Cetacea; Odontoceti; Delphinidae; Tursiops
# Tursiops truncatus
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Raoultella
# Raoultella ornithinolytica
# Bacteria; Firmicutes; Erysipelotrichia; Erysipelotrichales; Erysipelotrichaceae; Erysipelothrix
# Erysipelothrix rhusiopathiae str. Fujisawa
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Shewanellaceae; Shewanella
# Shewanella putrefaciens CN-32
# Bacteria; Actinobacteria; Micrococcales; Brevibacteriaceae; Brevibacterium
# Brevibacterium iodinum
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces; Streptomyces albidoflavus group
# Streptomyces coelicolor A3(2)
# Bacteria; Proteobacteria; Gammaproteobacteria; Aeromonadales; Aeromonadaceae; Aeromonas
# Aeromonas salmonicida
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus; Bacillus cereus group
# Bacillus cereus
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xanthomonas
# Xanthomonas campestris pv. raphani
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Serratia
# Serratia fonticola
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycolicibacterium
# Mycolicibacterium phlei
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Klebsiella
# Klebsiella aerogenes
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia neofelifaecis NRRL B-59395
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces himastatinicus ATCC 53653
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces platensis
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas espejiana DSM 9414
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces azureus
# Bacteria; Cyanobacteria; Oscillatoriophycideae; Oscillatoriales; Oscillatoriaceae; Phormidium
# Phormidium tenue NIES-30
# Bacteria; Firmicutes; Bacilli; Bacillales; Listeriaceae; Listeria
# Listeria weihenstephanensis
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Kluyvera
# Kluyvera cryocrescens NBRC 102467
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Lelliottia
# Lelliottia nimipressuralis
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas tolaasii NCPPB 2192
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces platensis
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacterium; Mycobacterium avium complex (MAC)
# Mycobacterium avium subsp. hominissuis TH135
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacterium; Mycobacterium avium complex (MAC)
# Mycobacterium avium subsp. hominissuis
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Perissodactyla; Equidae; Equus
# Equus caballus
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; Burkholderia cepacia complex
# Burkholderia pyrrocinia
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lacticaseibacillus
# Lactobacillus paracasei subsp. paracasei 8700:2
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacterium; Mycobacterium tuberculosis complex
# Mycobacterium tuberculosis variant bovis AF2122/97
# Bacteria; Tenericutes; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma
# Spiroplasma melliferum IPMB4A
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Kitasatospora
# Kitasatospora aureofaciens
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces indigocolor
# Bacteria; Cyanobacteria; Oscillatoriophycideae; Chroococcales; Microcystaceae; Microcystis
# Microcystis aeruginosa NIES-298
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Morganellaceae; Providencia
# Providencia stuartii MRSN 2154
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lacticaseibacillus
# Lactobacillus casei DSM 20011 = JCM 1134 = ATCC 393
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus
# Bacillus safensis
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycolicibacterium
# Mycolicibacterium vaccae 95051
# Bacteria; Bacteroidetes; Bacteroidia; Bacteroidales; Bacteroidaceae; Bacteroides
# Bacteroides fragilis NCTC 9343
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio splendidus
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus pasteuri SP1
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus pyogenes
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Rhodococcus
# Rhodococcus globerulus
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium flavescens
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces filamentosus NRRL 11379
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Aeribacillus
# Aeribacillus pallidus
# Bacteria; Proteobacteria; Epsilonproteobacteria; Campylobacterales; Campylobacteraceae; Campylobacter
# Campylobacter gracilis
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus haemolyticus
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus agalactiae
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces tricolor
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Enterobacter; Enterobacter cloacae complex
# Enterobacter cancerogenus
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Comamonadaceae; Rhodoferax
# Rhodoferax koreense
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium xerosis
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus
# Bacillus sp. (in: Bacteria)
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Klebsiella
# Klebsiella oxytoca 10-5243
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas marina
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Clavibacter
# Clavibacter michiganensis subsp. michiganensis
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas atlantica
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces azureus
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas plecoglossicida
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Psychrobacter
# Psychrobacter sp. P11F6
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Yersinia
# Yersinia pestis A1122
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia alkanivorans
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Gallinarum str. SG9
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio nigripulchritudo SOn1
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas chlororaphis subsp. piscium
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces sp.
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; Burkholderia cepacia complex
# Burkholderia ambifaria AMMD
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Paratyphi A
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Siphoviridae
# Tsukamurella phage TPA4
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactiplantibacillus
# Lactobacillus pentosus
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces avermitilis MA-4680 = NBRC 14893
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Siphoviridae
# Rothia phage Spartoi
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Typhimurium str. L-3553
# Bacteria; Actinobacteria; Propionibacteriales; Propionibacteriaceae; Propionibacterium
# Propionibacterium freudenreichii subsp. freudenreichii
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Erwinia
# Erwinia amylovora CFBP1430
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Dickeya
# Dickeya fangzhongdai
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Klebsiella
# Klebsiella pneumoniae
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces lividans 1326
# Bacteria; Actinobacteria; Corynebacteriales; Tsukamurellaceae; Tsukamurella
# Tsukamurella paurometabola DSM 20162
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio cyclitrophicus
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium radiodurans
# Bacteria; Cyanobacteria; Synechococcales; Prochloraceae; Prochlorococcus
# Prochlorococcus marinus subsp. marinus str. CCMP1375
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Cronobacter
# Cronobacter turicensis z3032
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Comamonadaceae; Delftia
# Delftia tsuruhatensis
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces griseofuscus
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Actinopterygii; Neopterygii; Teleostei; Ostariophysi; Cypriniformes; Cyprinidae; Cyprininae; Cyprinus
# Cyprinus carpio
# Bacteria; Proteobacteria; Gammaproteobacteria; Pasteurellales; Pasteurellaceae; Pasteurella
# Pasteurella multocida
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Cellulophaga
# Cellulophaga baltica 18
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus xylosus
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces toxytricini
# Bacteria; Firmicutes; Clostridia; Clostridiales; Clostridiaceae; Clostridium
# Clostridium tetani E88
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Acinetobacter; Acinetobacter calcoaceticus/baumannii complex
# Acinetobacter calcoaceticus
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio anguillarum 96F
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# [Brevibacterium] flavum ZL-1
# Bacteria; Actinobacteria; Bifidobacteriales; Bifidobacteriaceae; Bifidobacterium
# Bifidobacterium asteroides
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Pectobacterium
# Pectobacterium carotovorum subsp. carotovorum PC1
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus suis SC84
# Bacteria; Cyanobacteria; Nostocales; Aphanizomenonaceae; Nodularia
# Nodularia spumigena CCY9414
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Alcaligenaceae; Achromobacter
# Achromobacter xylosoxidans
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio natriegens NBRC 15636 = ATCC 14048 = DSM 759
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycolicibacterium
# Mycolicibacterium phlei
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus sp.
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas fluorescens
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Alteromonadaceae; Alteromonas
# Alteromonas confluentis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Enterococcaceae; Enterococcus
# Enterococcus faecium
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Morganellaceae; Morganella
# Morganella morganii
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; aphid secondary symbionts; Candidatus Hamiltonella
# Candidatus Hamiltonella defensa
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Photobacterium
# Photobacterium damselae
# Eukaryota; Amoebozoa; Discosea; Longamoebia; Centramoebida; Acanthamoebidae; Acanthamoeba
# Acanthamoeba castellanii
# Bacteria; Bacteroidetes; Bacteroidetes Order II. Incertae sedis; Rhodothermaceae; Salinibacter
# Salinibacter ruber DSM 13855
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Colwelliaceae; Thalassomonas
# Thalassomonas actiniarum
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Rhodococcus
# Rhodococcus hoagii
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces griseofuscus
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Morganellaceae; Providencia
# Providencia stuartii MRSN 2154
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus mitis
# Bacteria; Actinobacteria; Micrococcales; Micrococcaceae; Arthrobacter
# Arthrobacter globiformis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Leuconostocaceae; Oenococcus
# Oenococcus oeni
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Flavobacterium
# Flavobacterium psychrophilum
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas putida NBRC 14164
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus
# Bacillus halmapalus
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Roseovarius
# Roseovarius nubinhibens ISM
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodospirillales; Rhodospirillaceae; Azospirillum
# Azospirillum brasilense
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Flavobacterium
# Flavobacterium sp.
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium natoriense
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium paraoxydans 77MFTsu3.2
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus equi subsp. zooepidemicus
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus; Bacillus cereus group
# Bacillus anthracis str. 'Ames Ancestor'
# Bacteria; Firmicutes; Bacilli; Bacillales; Listeriaceae; Listeria
# Listeria monocytogenes
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus; Bacillus cereus group
# Bacillus mycoides
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Rhizobium/Agrobacterium group; Rhizobium
# Rhizobium leguminosarum bv. viciae WSM1455
# Eukaryota; Sar; Stramenopiles; Bigyra; Opalozoa; Bicosoecida; Cafeteriaceae; Cafeteria
# Cafeteria roenbergensis
# Eukaryota; Viridiplantae; Chlorophyta; Mamiellophyceae; Mamiellales; Bathycoccaceae; Ostreococcus
# Ostreococcus tauri
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lacticaseibacillus
# Lactobacillus rhamnosus GG
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio breoganii
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia amicalis CCMA-559
# Bacteria; Firmicutes; Bacilli; Bacillales; Sporolactobacillaceae; Sporolactobacillaceae incertae sedis
# [Bacillus] clarkii
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Alkalihalobacillus
# Bacillus alcalophilus ATCC 27647 = CGMCC 1.3604
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Artiodactyla; Ruminantia; Pecora; Bovidae; Caprinae; Ovis
# Ovis aries
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Comamonadaceae; Delftia
# Delftia acidovorans SPH-1
# Bacteria; Proteobacteria; Gammaproteobacteria; Pasteurellales; Pasteurellaceae; Mannheimia
# Mannheimia haemolytica USMARC_2286
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Nocardia
# Nocardia asteroides
# Bacteria; Bacteroidetes; Bacteroidia; Bacteroidales; Tannerellaceae; Parabacteroides
# Parabacteroides merdae
# Bacteria; Firmicutes; Clostridia; Clostridiales; Ruminococcaceae; Faecalibacterium
# Faecalibacterium prausnitzii
# Bacteria; Actinobacteria; Micrococcales; Micrococcaceae; Arthrobacter
# Arthrobacter sp.
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio cholerae MS6
# Bacteria; Proteobacteria; Alphaproteobacteria; Sphingomonadales; Sphingomonadaceae; Sphingomonas
# Sphingomonas paucimobilis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Levilactobacillus
# Lactobacillus brevis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Lactococcus
# Lactococcus lactis subsp. lactis
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Halobacteriales; Haloarculaceae; Haloarcula
# Haloarcula californiae ATCC 33799
# Eukaryota; Viridiplantae; Chlorophyta; core chlorophytes; Chlorodendrophyceae; Chlorodendrales; Chlorodendraceae; Tetraselmis; unclassified Tetraselmis
# Tetraselmis sp. CCMP 881
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Rhodococcus
# Rhodococcus rhodochrous
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; pseudomallei group
# Burkholderia pseudomallei
# Bacteria; Firmicutes; Bacilli; Bacillales; Paenibacillaceae; Paenibacillus
# Paenibacillus glucanolyticus
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas grimontii
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Rhodococcus
# Rhodococcus erythropolis PR4
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces scabiei 87.22
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Haloferacales; Haloferacaceae
# Halogranum rubrum
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; pseudomallei group
# Burkholderia thailandensis E264
# Bacteria; Firmicutes; Clostridia; Clostridiales; Clostridiaceae; Clostridium
# Clostridium tyrobutyricum
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Siphoviridae; Wilnyevirus; unclassified Wilnyevirus
# Streptomyces phage Muntaha
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Dickeya
# Dickeya solani IPO 2222
# Bacteria; Actinobacteria; Micrococcales; Micrococcaceae; Sinomonas
# Sinomonas atrocyanea
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; Burkholderia cepacia complex
# Burkholderia pyrrocinia
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia westfalica
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Hafniaceae; Edwardsiella
# Edwardsiella ictaluri
# Bacteria; Tenericutes; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma
# Spiroplasma kunkelii CR2-3x
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia malaquae NBRC 108250
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus aureus
# Bacteria; Firmicutes; Clostridia; Thermoanaerobacterales; Thermoanaerobacterales Family III. Incertae Sedis; Thermoanaerobacterium
# Thermoanaerobacterium saccharolyticum JW/SL-YS485
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium trichothecenolyticum
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycolicibacterium
# Mycolicibacterium aichiense
# Bacteria; Proteobacteria; Deltaproteobacteria; Myxococcales; Cystobacterineae; Myxococcaceae; Myxococcus
# Myxococcus xanthus DK 1622
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Nocardia
# Nocardia nova SH22a
# Bacteria; Proteobacteria; Epsilonproteobacteria; Campylobacterales; Campylobacteraceae; Campylobacter
# Campylobacter jejuni subsp. doylei
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus parauberis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Enterococcaceae; Enterococcus
# Enterococcus faecalis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus dysgalactiae
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Halobacteriales; Haloarculaceae; Haloarcula
# Haloarcula vallismortis
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Erwinia
# Erwinia billingiae Eb661
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Enterococcaceae; Enterococcus
# Enterococcus silesiacus
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium paraoxydans
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Typhi
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Loktanella
# Loktanella sp. S4079
# Bacteria; Chlamydiae; Chlamydiales; Chlamydiaceae; Chlamydia/Chlamydophila group; Chlamydia
# Chlamydia psittaci 6BC
# Bacteria
# bacterium
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Pseudoalteromonadaceae; Pseudoalteromonas
# Pseudoalteromonas phenolica
# Bacteria; Bacteroidetes; Bacteroidetes Order II. Incertae sedis; Rhodothermaceae; Salisaeta
# Salisaeta longa DSM 21114
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xylella
# Xylella fastidiosa Temecula1
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus; Bacillus cereus group
# Bacillus thuringiensis serovar morrisoni
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; Burkholderia cepacia complex
# Burkholderia cepacia
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Sulfitobacter
# Sulfitobacter sp.
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycobacterium
# Mycobacterium dioxanotrophicus
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus hominis
# Bacteria; Actinobacteria; Micrococcales; Microbacteriaceae; Microbacterium
# Microbacterium oxydans
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Alkalihalobacillus
# Bacillus bogoriensis ATCC BAA-922
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Limosilactobacillus
# Limosilactobacillus fermentum
# Bacteria; Tenericutes; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma
# Spiroplasma poulsonii
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Leuconostocaceae; Weissella
# Weissella cibaria
# Eukaryota; Haptista; Haptophyta; Prymnesiophyceae; Isochrysidales; Noelaerhabdaceae; Emiliania
# Emiliania huxleyi
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Erwinia
# Erwinia tracheiphila PSU-1
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces scabiei 87.22
# Bacteria; Tenericutes; Mollicutes; Entomoplasmatales; Spiroplasmataceae; Spiroplasma
# Spiroplasma citri
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Serratia
# Serratia rubidaea
# Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hexapoda; Insecta; Pterygota; Neoptera; Holometabola; Lepidoptera; Glossata; Ditrysia; Noctuoidea; Notodontidae; Pygaerinae; Clostera
# Clostera anastomosis
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Siphoviridae; Fromanvirus; unclassified Fromanvirus
# Mycobacterium phage Isca
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Siphoviridae; Neferthenavirus; unclassified Neferthenavirus
# Microbacterium phage Mercedes
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Citrobacter; Citrobacter freundii complex
# Citrobacter freundii
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Shigella
# Shigella dysenteriae
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Rhizobium/Agrobacterium group; Agrobacterium; Agrobacterium tumefaciens complex
# Agrobacterium tumefaciens
# Bacteria; Firmicutes; Bacilli; Bacillales; Paenibacillaceae; Paenibacillus
# Paenibacillus larvae subsp. larvae
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces albus
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xanthomonas
# Xanthomonas citri pv. citri
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Stenotrophomonas; Stenotrophomonas maltophilia group
# Stenotrophomonas maltophilia R551-3
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces venezuelae ATCC 10712
# Bacteria; Actinobacteria; Corynebacteriales; Tsukamurellaceae; Tsukamurella
# Tsukamurella tyrosinosolvens
# Bacteria; Firmicutes; Bacilli; Bacillales; Paenibacillaceae; Brevibacillus
# Brevibacillus laterosporus
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas asplenii
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Artiodactyla; Ruminantia; Pecora; Bovidae; Alcelaphinae; Connochaetes
# Connochaetes taurinus
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus gasseri ATCC 33323 = JCM 1131
# Bacteria; Firmicutes; Clostridia; Clostridiales; Peptostreptococcaceae; Clostridioides
# Clostridioides difficile
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus pneumoniae
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Comamonadaceae; Acidovorax
# Acidovorax citrulli AAC00-1
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella abortus 2308
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Erwiniaceae; Erwinia
# Erwinia tasmaniensis Et1/99
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces hygroscopicus subsp. hygroscopicus
# Bacteria; Actinobacteria; Micromonosporales; Micromonosporaceae; Actinoplanes
# Actinoplanes derwentensis
# Bacteria; Cyanobacteria; Oscillatoriophycideae; Oscillatoriales; Microcoleaceae; Planktothrix
# Planktothrix agardhii NIVA-CYA 126/8
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Lactococcus
# Lactococcus garvieae
# Viruses; Duplodnaviria; Heunggongvirae; Uroviricota; Caudoviricetes; Caudovirales; Myoviridae
# Streptomyces phage BRock
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Sinorhizobium/Ensifer group; Sinorhizobium
# Sinorhizobium fredii USDA 257
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus; Bacillus cereus group
# Bacillus thuringiensis Bt407
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus jensenii
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Flavobacterium
# Flavobacterium columnare
# Bacteria; Bacteroidetes; Bacteroidetes Order II. Incertae sedis; Rhodothermaceae; Rhodothermus
# Rhodothermus marinus DSM 4252
# Bacteria; Proteobacteria; Alphaproteobacteria; Caulobacterales; Caulobacteraceae; Caulobacter
# Caulobacter vibrioides
# Archaea; Crenarchaeota; Thermoprotei; Sulfolobales; Sulfolobaceae; Sulfolobus
# Sulfolobus islandicus Y.N.15.51
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Yersiniaceae; Serratia
# Serratia marcescens
# Bacteria; Proteobacteria; Gammaproteobacteria; Oceanospirillales; Oceanospirillaceae; Marinomonas
# Marinomonas mediterranea MMB-1
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Burkholderia; Burkholderia cepacia complex
# Burkholderia cenocepacia
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Enterobacter; Enterobacter cloacae complex
# Enterobacter asburiae
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces mirabilis
# Bacteria; Actinobacteria; Coriobacteriia; Eggerthellales; Eggerthellaceae; Eggerthella
# Eggerthella lenta
# Bacteria; Actinobacteria; Corynebacteriales; Nocardiaceae; Nocardia
# Nocardia otitidiscaviarum
# Bacteria; Proteobacteria; Gammaproteobacteria; Oceanospirillales; Oceanospirillaceae; Nitrincola
# Nitrincola lacisaponensis
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Pectobacteriaceae; Dickeya; unclassified Dickeya
# Dickeya sp. Secpp 1600
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces virginiae
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces viridochromogenes DSM 40736
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xanthomonas
# Xanthomonas fragariae
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella melitensis bv. 1 str. 16M
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Pseudomonadaceae; Pseudomonas
# Pseudomonas aeruginosa PA38182
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Rhizobiaceae; Liberibacter
# Candidatus Liberibacter asiaticus str. gxpsy
# Eukaryota; Sar; Stramenopiles; Pelagophyceae; Pelagomonadales; Aureococcus
# Aureococcus anophagefferens
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Newport
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces sp. SPB78
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Morganellaceae; Proteus
# Proteus mirabilis HI4320
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Streptococcaceae; Streptococcus
# Streptococcus gordonii str. Challis substr. CH1
# Bacteria; Spirochaetes; Leptospirales; Leptospiraceae; Leptospira
# Leptospira biflexa
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodospirillales; Acetobacteraceae; Gluconobacter
# Gluconobacter cerinus
# Bacteria; Actinobacteria; Corynebacteriales; Gordoniaceae; Gordonia
# Gordonia rubripertincta
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Shigella
# Shigella boydii
# Bacteria; Firmicutes; Bacilli; Bacillales; Staphylococcaceae; Staphylococcus
# Staphylococcus capitis subsp. capitis
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Alcaligenaceae; Bordetella
# Bordetella bronchiseptica
# Bacteria; Proteobacteria; Gammaproteobacteria; Aeromonadales; Aeromonadaceae; Aeromonas
# Aeromonas media
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella inopinata BO1
# Bacteria; Actinobacteria; Micrococcales; Brevibacteriaceae; Brevibacterium
# Brevibacterium sandarakinum
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Vibrio
# Vibrio harveyi
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces griseus
# Bacteria; Bacteroidetes; Flavobacteriia; Flavobacteriales; Flavobacteriaceae; Cellulophaga
# Cellulophaga algicola DSM 14237
# Archaea; Euryarchaeota; Methanomada group; Methanobacteria; Methanobacteriales; Methanobacteriaceae; Methanothermobacter
# Methanothermobacter thermautotrophicus str. Delta H
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces viridochromogenes DSM 40736
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Halobacteriales; Haloarculaceae; Haloarcula
# Haloarcula sinaiiensis ATCC 33800
# Bacteria; Proteobacteria; Gammaproteobacteria; Xanthomonadales; Xanthomonadaceae; Xanthomonas
# Xanthomonas vesicatoria ATCC 35937
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella abortus 2308
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Alcaligenaceae; Achromobacter
# Achromobacter animicus
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Rhodobacter
# Rhodobacter capsulatus
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Natrialbales; Natrialbaceae; Natrialba
# Natrialba magadii ATCC 43099
# Bacteria; Tenericutes; Mollicutes; Mycoplasmataceae; Mycoplasma
# Mycoplasma arthritidis
# Bacteria; Firmicutes; Bacilli; Bacillales; Listeriaceae; Brochothrix
# Brochothrix thermosphacta
# Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi; Mammalia; Eutheria; Laurasiatheria; Artiodactyla; Ruminantia; Pecora; Bovidae; Alcelaphinae; Damaliscus
# Damaliscus lunatus
# Bacteria; Actinobacteria; Streptomycetales; Streptomycetaceae; Streptomyces
# Streptomyces sp. C
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Leuconostocaceae; Leuconostoc
# Leuconostoc mesenteroides subsp. mesenteroides
# Bacteria; Firmicutes; Clostridia; Clostridiales; Clostridiaceae; Clostridium
# Clostridium perfringens ATCC 13124
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Roseobacter
# Roseobacter denitrificans
# Archaea; Crenarchaeota; Thermoprotei; Sulfolobales; Sulfolobaceae; Acidianus
# Acidianus brierleyi
# Bacteria; Proteobacteria; Gammaproteobacteria; Pseudomonadales; Moraxellaceae; Acinetobacter; Acinetobacter calcoaceticus/baumannii complex
# Acinetobacter baumannii
# Bacteria; Proteobacteria; Gammaproteobacteria; Alteromonadales; Idiomarinaceae; Idiomarina
# Idiomarina sp. 5.13
# Bacteria; Actinobacteria; Micrococcales; Micrococcaceae; Sinomonas
# Sinomonas atrocyanea
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhizobiales; Brucellaceae; Brucella
# Brucella suis 1330
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Paracoccus
# Paracoccus marcusii
# Bacteria; Proteobacteria; Gammaproteobacteria; Aeromonadales; Aeromonadaceae; Aeromonas
# Aeromonas hydrophila
# Bacteria; Proteobacteria; Oligoflexia; Bdellovibrionales; Bdellovibrionaceae; Bdellovibrio
# Bdellovibrio bacteriovorus HD100
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. enterica serovar Enteritidis
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Salmonella
# Salmonella enterica subsp. diarizonae serovar 59:z10:-
# Bacteria; Proteobacteria; Gammaproteobacteria; Oceanospirillales; Halomonadaceae; Halomonas
# Halomonas aquamarina
# Archaea; Euryarchaeota; Stenosarchaea group; Halobacteria; Haloferacales; Halorubraceae; Halorubrum; unclassified Halorubrum
# Halorubrum sp. BOL3-1
# Bacteria; Proteobacteria; Gammaproteobacteria; Pasteurellales; Pasteurellaceae; Glaesserella
# Glaesserella parasuis SH0165
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium vitaeruminis DSM 20294
# Bacteria; Firmicutes; Bacilli; Bacillales; Bacillaceae; Bacillus
# Bacillus megaterium
# Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Citrobacter
# Citrobacter rodentium ICC168
# Bacteria; Actinobacteria; Corynebacteriales; Tsukamurellaceae; Tsukamurella
# Tsukamurella paurometabola
# Bacteria; Proteobacteria; Betaproteobacteria; Burkholderiales; Burkholderiaceae; Ralstonia
# Ralstonia solanacearum OE1-1
# Bacteria; Actinobacteria; Corynebacteriales; Corynebacteriaceae; Corynebacterium
# Corynebacterium vitaeruminis DSM 20294
# Bacteria; Proteobacteria; Alphaproteobacteria; Rhodobacterales; Rhodobacteraceae; Celeribacter
# Celeribacter marinus
# Bacteria; Proteobacteria; Gammaproteobacteria; Vibrionales; Vibrionaceae; Aliivibrio
# Aliivibrio fischeri
# Bacteria; Actinobacteria; Corynebacteriales; Mycobacteriaceae; Mycolicibacterium
# Mycolicibacterium smegmatis
# Bacteria; Firmicutes; Bacilli; Lactobacillales; Lactobacillaceae; Lactobacillus
# Lactobacillus johnsonii
# Bacteria; Proteobacteria; Gammaproteobacteria; Pasteurellales; Pasteurellaceae; Haemophilus
# Haemophilus influenzae
# Bacteria; Proteobacteria; Epsilonproteobacteria; Campylobacterales; Helicobacteraceae; Helicobacter
# Helicobacter pylori Puno135

# %%
# If wish to save to csv
# df.to_csv("Host_taxonomy.csv")

# %%
# Number of Hosts that are Eukaryota
df[df['Taxonomy'].str.startswith('E')].shape
# Out:
#           accn                         Name  \
# 24    KY464958     Apis mellifera lamarckii
# 39    KC900889          Phaeocystis globosa
# 44    KT970065         Tipula cockerelliana
# 45   NC_014574       Culex quinquefasciatus
# 47    KP691602           Dunaliella viridis
# 56    GG663735  Micromonas pusilla CCMP1545
# 96   NC_001700                  Felis catus
# 99    HQ914635         Chlorella variabilis
# 101   EU557093           Tursiops truncatus
# 126   MF925712               Equus caballus
# 186   MH202953              Cyprinus carpio
# 209  NC_001637     Acanthamoeba castellanii
# 231   AF193903      Cafeteria roenbergensis
# 232   KC990831           Ostreococcus tauri
# 238   MH841968                   Ovis aries
# 250   KU167097     Tetraselmis sp. CCMP 881
# 299  NC_007288            Emiliania huxleyi
# 304   MH286069         Clostera anastomosis
# 318   JN632628        Connochaetes taurinus
# 352  NC_012898  Aureococcus anophagefferens
# 379  NC_023543           Damaliscus lunatus
#
#                                               Taxonomy
# 24   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 39   Eukaryota; Haptista; Haptophyta; Prymnesiophyc...
# 44   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 45   Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 47   Eukaryota; Viridiplantae; Chlorophyta; core ch...
# 56   Eukaryota; Viridiplantae; Chlorophyta; Mamiell...
# 96   Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 99   Eukaryota; Viridiplantae; Chlorophyta; core ch...
# 101  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 126  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 186  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 209  Eukaryota; Amoebozoa; Discosea; Longamoebia; C...
# 231  Eukaryota; Sar; Stramenopiles; Bigyra; Opalozo...
# 232  Eukaryota; Viridiplantae; Chlorophyta; Mamiell...
# 238  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 250  Eukaryota; Viridiplantae; Chlorophyta; core ch...
# 299  Eukaryota; Haptista; Haptophyta; Prymnesiophyc...
# 304  Eukaryota; Metazoa; Ecdysozoa; Arthropoda; Hex...
# 318  Eukaryota; Metazoa; Chordata; Craniata; Verteb...
# 352  Eukaryota; Sar; Stramenopiles; Pelagophyceae; ...
# 379  Eukaryota; Metazoa; Chordata; Craniata; Verteb...

# %%
# Number of Hosts that are Archea
df[df['Taxonomy'].str.startswith('A')].shape
# Out:
# (13, 3)

# %%
# Number of Hosts that are bacteria
df[df['Taxonomy'].str.startswith('B')].shape
# Out:
# (369, 3)

# %%
# Hosts that are not bacteria
to_exclude = df[~df['Taxonomy'].str.startswith('B')].accn.to_list()

# %%
# Remaining hosts
filtered = combined[~combined['host'].isin(to_exclude)]
df[df['Taxonomy'].str.startswith('B')]
# Out:
#                   accn                         Name  \
# 0             CP001713  Chlamydia pneumoniae LPCoLN
# 2        NZ_CP042449.1         Vibrio alginolyticus
# 3        NZ_CP013990.1     Leclercia adecarboxylata
# 4             CP000031      Ruegeria pomeroyi DSS-3
# 5         PEKX01000007              Pseudomonas sp.
# ..                 ...                          ...
# 404  NZ_SJSX01000001.1          Aliivibrio fischeri
# 405      NZ_LN831039.1  Mycolicibacterium smegmatis
# 406      NZ_CP029614.1      Lactobacillus johnsonii
# 407      NZ_CP009610.1       Haemophilus influenzae
# 408        NC_017379.1  Helicobacter pylori Puno135
#
#                                               Taxonomy
# 0    Bacteria; Chlamydiae; Chlamydiales; Chlamydiac...
# 2    Bacteria; Proteobacteria; Gammaproteobacteria;...
# 3    Bacteria; Proteobacteria; Gammaproteobacteria;...
# 4    Bacteria; Proteobacteria; Alphaproteobacteria;...
# 5    Bacteria; Proteobacteria; Gammaproteobacteria;...
# ..                                                 ...
# 404  Bacteria; Proteobacteria; Gammaproteobacteria;...
# 405  Bacteria; Actinobacteria; Corynebacteriales; M...
# 406  Bacteria; Firmicutes; Bacilli; Lactobacillales...
# 407  Bacteria; Proteobacteria; Gammaproteobacteria;...
# 408  Bacteria; Proteobacteria; Epsilonproteobacteri...
#
# [369 rows x 3 columns]

# %%
len([i.split(";")[-1] for i in df[df['Taxonomy'].str.startswith('B')].Taxonomy.to_list() ])
# Out:
# 369

# %%
species = [i.split(";")[-1] for i in df[df['Taxonomy'].str.startswith('B')].Taxonomy.to_list()]
keys = set(species)
libs = {}

for s in species:
    if s in libs:
        libs[s] += 1
    else:
        libs[s] = 1

print("{} unique species".format(len(libs)))
{k: v for k, v in sorted(libs.items(), key=lambda item: item[1], reverse=True)}
# Out:
# 162 unique species
# {' Streptomyces': 28,
#  ' Streptococcus': 13,
#  ' Vibrio': 11,
#  ' Pseudomonas': 11,
#  ' Gordonia': 10,
#  ' Staphylococcus': 9,
#  ' Microbacterium': 9,
#  ' Corynebacterium': 7,
#  ' Salmonella': 7,
#  ' Lactobacillus': 6,
#  ' Pseudoalteromonas': 6,
#  ' Brucella': 6,
#  ' Xanthomonas': 5,
#  ' Bacillus': 5,
#  ' Erwinia': 5,
#  ' Bacillus cereus group': 5,
#  ' Mycolicibacterium': 5,
#  ' Burkholderia cepacia complex': 5,
#  ' Clostridium': 4,
#  ' Nocardia': 4,
#  ' Spiroplasma': 4,
#  ' Rhodococcus': 4,
#  ' Chlamydia': 3,
#  ' Pectobacterium': 3,
#  ' Acinetobacter': 3,
#  ' Yersinia': 3,
#  ' Rhizobium': 3,
#  ' Mycobacterium avium complex (MAC)': 3,
#  ' Brevibacterium': 3,
#  ' Arthrobacter': 3,
#  ' Lactiplantibacillus': 3,
#  ' Shigella': 3,
#  ' Enterobacter cloacae complex': 3,
#  ' Aeromonas': 3,
#  ' Serratia': 3,
#  ' Klebsiella': 3,
#  ' Lacticaseibacillus': 3,
#  ' Tsukamurella': 3,
#  ' Enterococcus': 3,
#  ' Flavobacterium': 3,
#  ' Edwardsiella': 2,
#  ' Cronobacter': 2,
#  ' Rhodobacter': 2,
#  ' Sinorhizobium': 2,
#  ' Ralstonia': 2,
#  ' Leuconostoc': 2,
#  ' Mycoplasma': 2,
#  ' Citrobacter': 2,
#  ' Streptomyces albidoflavus group': 2,
#  ' Parabacteroides': 2,
#  ' Bacteroides': 2,
#  ' Listeria': 2,
#  ' Providencia': 2,
#  ' Campylobacter': 2,
#  ' Dickeya': 2,
#  ' Delftia': 2,
#  ' Cellulophaga': 2,
#  ' Acinetobacter calcoaceticus/baumannii complex': 2,
#  ' Achromobacter': 2,
#  ' Alkalihalobacillus': 2,
#  ' Lactococcus': 2,
#  ' pseudomallei group': 2,
#  ' Paenibacillus': 2,
#  ' Sinomonas': 2,
#  ' Leclercia': 1,
#  ' Ruegeria': 1,
#  ' Salinivibrio': 1,
#  ' Actinomyces': 1,
#  ' Dinoroseobacter': 1,
#  ' Aggregatibacter': 1,
#  ' Iodobacter': 1,
#  ' Cutibacterium': 1,
#  ' Leptolyngbya': 1,
#  ' Mycobacteroides': 1,
#  ' Fusobacterium': 1,
#  ' Tetrasphaera': 1,
#  ' Mesorhizobium': 1,
#  ' Thermus': 1,
#  ' Trichormus': 1,
#  ' Riemerella': 1,
#  ' Acholeplasma': 1,
#  ' Nonlabens': 1,
#  ' Geobacillus': 1,
#  ' Tenacibaculum': 1,
#  ' Geobacillus thermoleovorans group': 1,
#  ' Sodalis': 1,
#  ' unclassified Geobacillus': 1,
#  ' Candidatus Puniceispirillum': 1,
#  ' Candidatus Pelagibacter': 1,
#  ' Pantoea agglomerans group': 1,
#  ' Raoultella': 1,
#  ' Erysipelothrix': 1,
#  ' Shewanella': 1,
#  ' Phormidium': 1,
#  ' Kluyvera': 1,
#  ' Lelliottia': 1,
#  ' Mycobacterium tuberculosis complex': 1,
#  ' Kitasatospora': 1,
#  ' Microcystis': 1,
#  ' Aeribacillus': 1,
#  ' Rhodoferax': 1,
#  ' Clavibacter': 1,
#  ' Psychrobacter': 1,
#  ' Propionibacterium': 1,
#  ' Prochlorococcus': 1,
#  ' Pasteurella': 1,
#  ' Bifidobacterium': 1,
#  ' Nodularia': 1,
#  ' Alteromonas': 1,
#  ' Morganella': 1,
#  ' Candidatus Hamiltonella': 1,
#  ' Photobacterium': 1,
#  ' Salinibacter': 1,
#  ' Thalassomonas': 1,
#  ' Oenococcus': 1,
#  ' Roseovarius': 1,
#  ' Azospirillum': 1,
#  ' Sporolactobacillaceae incertae sedis': 1,
#  ' Mannheimia': 1,
#  ' Faecalibacterium': 1,
#  ' Sphingomonas': 1,
#  ' Levilactobacillus': 1,
#  ' Thermoanaerobacterium': 1,
#  ' Myxococcus': 1,
#  ' Loktanella': 1,
#  'Bacteria': 1,
#  ' Salisaeta': 1,
#  ' Xylella': 1,
#  ' Sulfitobacter': 1,
#  ' Mycobacterium': 1,
#  ' Limosilactobacillus': 1,
#  ' Weissella': 1,
#  ' Citrobacter freundii complex': 1,
#  ' Agrobacterium tumefaciens complex': 1,
#  ' Stenotrophomonas maltophilia group': 1,
#  ' Brevibacillus': 1,
#  ' Clostridioides': 1,
#  ' Acidovorax': 1,
#  ' Actinoplanes': 1,
#  ' Planktothrix': 1,
#  ' Rhodothermus': 1,
#  ' Caulobacter': 1,
#  ' Marinomonas': 1,
#  ' Eggerthella': 1,
#  ' Nitrincola': 1,
#  ' unclassified Dickeya': 1,
#  ' Liberibacter': 1,
#  ' Proteus': 1,
#  ' Leptospira': 1,
#  ' Gluconobacter': 1,
#  ' Bordetella': 1,
#  ' Brochothrix': 1,
#  ' Roseobacter': 1,
#  ' Idiomarina': 1,
#  ' Paracoccus': 1,
#  ' Bdellovibrio': 1,
#  ' Halomonas': 1,
#  ' Glaesserella': 1,
#  ' Celeribacter': 1,
#  ' Aliivibrio': 1,
#  ' Haemophilus': 1,
#  ' Helicobacter': 1}

# %%
# Unique phage accession
len(set(filtered['phage']))
# Out:
# 5446

# %%
# Total phage accession
len(filtered['phage'])
# Out:
# 5622

# %% [markdown]
# <p style="color:blue"> Given there are close to 400 hosts, yet only about 160 unique species, we might wonder if we should aggregate all these species together to produce a more uniform dataset. I decided not to, since there are 5446 out of 5622 unique phage accession numbers, which means that viruses are infecting different strands of the bacteria in the same species.<p/>

# %%
filtered.to_csv("Combined2.csv")

# %% [markdown]
# #### Not Used

# %%
multiple_host = set()

tmp = filtered.groupby('phage')['host'].apply(list).reset_index(name='new')
for i in range(tmp['new'].to_numpy().shape[0]):
    row = tmp['new'].to_numpy()[i]
    if len(row) > 1:
        multiple_host.add(tuple(row))
        
multiple_host
# Out:
# {('AL645882', 'NZ_BBQG01000095.1'),
#  ('AL645882', 'NZ_JAANOB010000217.1'),
#  ('AL645882', 'NZ_MDFG01000001.1'),
#  ('CP000388', 'NZ_CP011028.1'),
#  ('CP000388', 'NZ_CP023464.1'),
#  ('CP019892', 'MN294681.1'),
#  ('CP024902', 'NZ_CP008781.1', 'NZ_CP024902.1'),
#  ('JTHH01000008', 'NZ_CM000747.1'),
#  ('JTHH01000008', 'NZ_CP011007.1'),
#  ('JTHH01000008', 'NZ_CP053931.1', 'NZ_CM000747.1'),
#  ('NC_003155.5', 'NC_016111.1'),
#  ('NC_007530.2', 'NZ_CP053931.1'),
#  ('NC_013961.1', 'NZ_CP023567.1'),
#  ('NC_021505.1', 'NZ_CP048408.1'),
#  ('NZ_CABEIC010000001.1',
#   'NZ_CP041695.1',
#   'NC_012490.1',
#   'NZ_QEOC01000001.1',
#   'NC_018681.1'),
#  ('NZ_CABEIC010000001.1',
#   'NZ_LR134352.1',
#   'NZ_CP006850.1',
#   'NZ_AWTB01000001.1',
#   'NZ_BAOP01000115.1'),
#  ('NZ_CP013197.1', 'NZ_AMGI01000001.1'),
#  ('NZ_CP027793.1', 'LT708304.1'),
#  ('NZ_CP032757.1', 'NZ_CP030105.1'),
#  ('NZ_CP045235.1', 'NZ_MUTR01000001.1'),
#  ('NZ_CP048408.1',
#   'NC_021505.1',
#   'NZ_LS999521.1',
#   'NC_010554.1',
#   'NZ_AP014524.1'),
#  ('NZ_LN831039.1', 'CP018363', 'NZ_AP012555.1'),
#  ('NZ_LN831039.1', 'CP020809'),
#  ('NZ_LN831039.1', 'CP020809', 'NZ_CP011491.1'),
#  ('NZ_LN831039.1', 'LT708304.1'),
#  ('NZ_LPTR01000009.1', 'NZ_MSJW02000001.1', 'NZ_NQCD01000010.1'),
#  ('NZ_NQCD01000010.1', 'NC_013716.1'),
#  ('NZ_QTTZ01000001', 'MN294681.1')}
